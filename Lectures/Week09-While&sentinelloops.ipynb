# %% [markdown]
# # While loops
#
# When it comes to data processing in python, the while loop is only deployed when the for loop won't cut it.
#
# While loops are the standard way to loop for some languages, but not so much in python.  There are certain tasks, such as interactive programs, where the while loop is almost always what you use.
#
# This class is dealing with data, which is usually in files so you know exactly how many times to run.
#
# The while loop is valuable in the cases when you don't know how many times you'll need to run through things.
#
# Let's look at a real data example here.
#
# So we know that there are states happening in the file, but we don't know how many universities will be listed under each.  We can use a combination of pattern here:
#
# * a decision tree to filter the lines we have found into their meaning groups
# * a main and sub accumalator pattern that you used in the week where you were going over a file and using an accumulaor on each of the lines, and then collecting all of the results in a final accumulator.
#
# Let's do the easy stuff first.

# %% [markdown]
# ## pattern 1: filter all the things
#
# Taking a look at the file in question, we can see that there are two kinds of lines:
#
# * a line talking about a state
# * a line talking about a university
#
# We need to figure out how to detect these differences.  Going back to our previous discussions:
#
# 1. we could try and detect is only a state name is mentioned in a line
# 2. we could exploit the known and steady sturucture
#
# Let's go for item 2 first.
#
# * some of the universities have () in the names
# * some of the universities have footnotes, and therefor end withd [a number]
#
# But is this something regular enough to depend on?
#
# We can test the () first, and let's print out what that might tell us about the states, since that is the smaller category.

# %%
fileio = open('crappystatedata.txt', 'r')

text = fileio.read()
lines = text.split("\n")
fileio.close()

for line in lines:
    if '(' in line and ')' in line:
        print("----")
    else:
        print("this in a state:", line)
# Out:
# this in a state: Alabama[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Alaska[edit]
# ----
# ----
# ----
# ----
# ----
# this in a state: Arizona[edit]
# ----
# ----
# this in a state: Gilbert[14]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Arkansas[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: California[edit]
# ----
# ----
# ----
# ----
# this in a state: Antioch[14]
# ----
# this in a state: Arden-Arcade[14]
# this in a state: Azusa
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Corona
# ----
# ----
# this in a state: Daly City
# ----
# this in a state: Downey
# this in a state: East Los Angeles
# ----
# this in a state: El Monte
# ----
# this in a state: Escondido
# ----
# this in a state: Fontana
# ----
# ----
# ----
# this in a state: Garden Grove
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Rialto
# this in a state: Richmond[14]
# ----
# ----
# ----
# ----
# this in a state: Sacramento :
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Simi Valley
# ----
# ----
# this in a state: Sunnyvale[14]
# this in a state: Temecula
# this in a state: Torrance
# ----
# ----
# ----
# ----
# this in a state: Victorville
# ----
# this in a state: Westminster
# this in a state: West Covina
# ----
# this in a state: Colorado[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Connecticut[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Delaware[edit]
# ----
# ----
# ----
# ----
# this in a state: District of Columbia[edit]
# ----
# this in a state: Florida[edit]
# ----
# ----
# ----
# this in a state: Brandon
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Hollywood
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Sunrise
# ----
# ----
# ----
# this in a state: Georgia[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Monroe
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Hawaii[edit]
# ----
# ----
# this in a state: Idaho[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Illinois[edit]
# ----
# this in a state: Aurora
# ----
# ----
# ----
# this in a state: Chicago :
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Indiana[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Iowa[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Kansas[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Kentucky[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Louisiana[edit]
# ----
# ----
# ----
# ----
# this in a state: Metairie
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Maine[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Maryland[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Massachusetts[edit]
# ----
# ----
# ----
# ----
# ----
# this in a state: The Colleges of Worcester Consortium:
# ----
# ----
# ----
# ----
# ----
# this in a state: The Five College Region of Western Massachusetts:
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Michigan[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Detroit :
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Sterling Heights
# ----
# ----
# this in a state: Minnesota[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Mississippi[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Missouri[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Montana[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Nebraska[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Nevada[edit]
# ----
# ----
# ----
# ----
# ----
# this in a state: New Hampshire[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: New Jersey[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Paterson
# ----
# ----
# ----
# this in a state: New Mexico[edit]
# ----
# ----
# ----
# ----
# ----
# this in a state: Rio Rancho
# ----
# ----
# this in a state: New York[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: North Carolina[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Cary
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: North Dakota[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Ohio[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Cleveland:[46]
# ----
# ----
# ----
# ----
# this in a state: Columbus :
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Oklahoma[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Oregon[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Pennsylvania[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Johnstown :
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Philadelphia :
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Pittsburgh:[48]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Rhode Island[edit]
# ----
# ----
# ----
# this in a state: Providence :
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: South Carolina[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: South Dakota[edit]
# this in a state: Aberdeen
# ----
# ----
# ----
# ----
# ----
# this in a state: Tennessee[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Memphis (Baptist College of Health Sciences, Christian Brothers University, LeMoyne-Owen College, Memphis College of Art, Rhodes College, Southern College of Optometry, Southwest Tennessee Community College, Union University - Germantown campus, University of Memphis, University of Tennessee Health Science Center
# ----
# ----
# ----
# ----
# ----
# this in a state: Texas[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Carrollton
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Grand Prairie
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: McKinney
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Utah[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Vermont[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Virginia[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Washington[edit]
# ----
# ----
# ----
# ----
# this in a state: Kent
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: West Virginia[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Wisconsin[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Wyoming[edit]
# ----

# %% [markdown]
# Ouch, we've got some universities in this.  Some of them have the [] in there, so we can add that in next.

# %%
fileio = open('crappystatedata.txt', 'r')

text = fileio.read()
lines = text.split("\n")
fileio.close()

for line in lines:
    if '(' in line and ')' in line:
        print("----")
    elif '[' in line and ']' in line:
        print("----")
    else:
        print("this in a state:", line)
# Out:
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Azusa
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Corona
# ----
# ----
# this in a state: Daly City
# ----
# this in a state: Downey
# this in a state: East Los Angeles
# ----
# this in a state: El Monte
# ----
# this in a state: Escondido
# ----
# this in a state: Fontana
# ----
# ----
# ----
# this in a state: Garden Grove
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Rialto
# ----
# ----
# ----
# ----
# ----
# this in a state: Sacramento :
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Simi Valley
# ----
# ----
# ----
# this in a state: Temecula
# this in a state: Torrance
# ----
# ----
# ----
# ----
# this in a state: Victorville
# ----
# this in a state: Westminster
# this in a state: West Covina
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Brandon
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Hollywood
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Sunrise
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Monroe
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Aurora
# ----
# ----
# ----
# this in a state: Chicago :
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Metairie
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: The Colleges of Worcester Consortium:
# ----
# ----
# ----
# ----
# ----
# this in a state: The Five College Region of Western Massachusetts:
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Detroit :
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Sterling Heights
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Paterson
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Rio Rancho
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Cary
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Columbus :
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Johnstown :
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Philadelphia :
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Providence :
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Aberdeen
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Memphis (Baptist College of Health Sciences, Christian Brothers University, LeMoyne-Owen College, Memphis College of Art, Rhodes College, Southern College of Optometry, Southwest Tennessee Community College, Union University - Germantown campus, University of Memphis, University of Tennessee Health Science Center
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Carrollton
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Grand Prairie
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: McKinney
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Kent
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----

# %% [markdown]
# That made things worse. We've lost the states completely.

# %%
fileio = open('crappystatedata.txt', 'r')

text = fileio.read()
lines = text.split("\n")
fileio.close()

for line in lines:
    if '(' in line and ')' in line and '[' in line and ']' in line:
        print("----")
    else:
        print("this in a state:", line)
# Out:
# this in a state: Alabama[edit]
# ----
# ----
# this in a state: Dothan (Fortis College, Troy University Dothan Campus, Alabama College of Osteopathic Medicine)
# this in a state: Florence (University of North Alabama)
# this in a state: Homewood (Samford University)
# this in a state: Huntsville (University of Alabama, Huntsville)
# ----
# ----
# ----
# ----
# this in a state: Montgomery (Alabama State University, Huntingdon College, Auburn University at Montgomery, H. Councill Trenholm State Technical College, Faulkner University)
# ----
# ----
# ----
# this in a state: Alaska[edit]
# ----
# ----
# this in a state: Juneau (University of Alaska Southeast)
# this in a state: Ketchikan (University of Alaska Southeast-extended campus)
# this in a state: Sitka (University of Alaska Southeast-extended campus)
# this in a state: Arizona[edit]
# ----
# ----
# this in a state: Gilbert[14]
# ----
# this in a state: Lake Havasu City (ASU Colleges at Lake Havasu City, Northern Arizona University extended campus)
# ----
# ----
# ----
# this in a state: Prescott (Embry–Riddle Aeronautical University, Yavapai College, Prescott College, Northern Arizona University, Old Dominion University)
# ----
# ----
# this in a state: Tucson (University of Arizona, Tucson College, Brown Mackie College, Brookline College, University of Phoenix, The Art Institute of Tucson, Prescott College branch campus,Northern Arizona University branch campus,The Art Center Design College, Wayland Baptist University)
# this in a state: Arkansas[edit]
# ----
# ----
# ----
# this in a state: Fort Smith (University of Arkansas at Fort Smith, Webster University satellite campus, John Brown University satellite campus, Arkansas College of Osteopathic Medicine)
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: California[edit]
# this in a state: Acton (Larry H. Layton School of Law)
# this in a state: Alhambra (Platt College, Alhambra branch of Everest College, Los Angeles Campus of Alliant International University, University of Southern California's Health Sciences Alhambra campus)
# this in a state: Anaheim (Anaheim University, California Institute of Technology (SCIT), Bristol University)
# ----
# this in a state: Antioch[14]
# ----
# this in a state: Arden-Arcade[14]
# this in a state: Azusa
# ----
# ----
# this in a state: Burbank (Woodbury University)
# this in a state: Camarillo (California State University Channel Islands)
# this in a state: Carson (California State University, Dominguez Hills)
# this in a state: Cerritos (Cerritos College, Fremont College, Irvine University College of Law)
# ----
# this in a state: Chino Hills (Biola University (Satellite Campus))
# this in a state: Chula Vista (Southwestern College)
# ----
# ----
# this in a state: Compton (El Camino College)
# ----
# this in a state: Corona
# this in a state: Costa Mesa (Orange Coast College, Vanguard University, Whittier Law School (a satellite of Whittier College) and National University satellite campus)
# ----
# this in a state: Daly City
# ----
# this in a state: Downey
# this in a state: East Los Angeles
# this in a state: El Cajon (Cuyamaca College, Grossmont College, San Diego Christian College)
# this in a state: El Monte
# ----
# this in a state: Escondido
# ----
# this in a state: Fontana
# ----
# ----
# this in a state: Fullerton (California State University, Fullerton, Western State College of Law at Argosy University, Hope International University, Marshall B. Ketchum University)
# this in a state: Garden Grove
# this in a state: Glendale (Glendale University College of Law)
# this in a state: Hawthorne (Los Angeles Southwest College, El Camino College)
# ----
# this in a state: Huntington Beach (Golden West College)
# this in a state: Indio (California Desert Trial Academy College of Law)
# this in a state: Inglewood (University of West Los Angeles)
# this in a state: Irvine (University of California, Irvine, Western State College of Law at Argosy University)
# ----
# this in a state: Lancaster (University of Antelope Valley, Antelope Valley College, satellite campus of California State University, Bakersfield, Charter College)
# this in a state: La Mesa (McMillan Academy of Law)
# this in a state: La Verne (University of La Verne)
# this in a state: Loma Linda (Loma Linda University)
# ----
# ----
# this in a state: Chatsworth (University of West Los Angeles)
# this in a state: Downtown Los Angeles (Peoples College of Law)
# this in a state: Mid-Wilshire (Southwestern University School of Law)
# this in a state: Pico-Union (Loyola Law School)
# this in a state: University Park (University of Southern California)
# this in a state: Westchester (Loyola Marymount University)
# ----
# this in a state: Merced (University of California, Merced)
# ----
# this in a state: Moreno Valley (Chapman University, Moreno Valley College)
# ----
# this in a state: Norwalk (Cerritos College)
# ----
# this in a state: Oceanside (Mira Costa College)
# this in a state: Ontario (University of La Verne College of Law)
# this in a state: Orange (Chapman University, Pacific West College of Law)
# ----
# this in a state: Palmdale (Chapman University satellite campus, University of Antelope Valley, University of La Verne satellite campus)
# this in a state: Palo Alto (Stanford University)
# ----
# this in a state: Pleasant Hill (John F. Kennedy University)
# ----
# this in a state: Rancho Cucamonga (Chaffey College and satellite campuses of the University of La Verne, Cambridge College, University of Redlands, Everest College, and University of Phoenix)
# ----
# this in a state: Redlands (University of Redlands)
# this in a state: Rialto
# this in a state: Richmond[14]
# this in a state: Ridgecrest (Pinnacles School of Law)
# this in a state: Riverside (University of California, Riverside, California Baptist University, La Sierra University, California Southern Law School)
# this in a state: Rocklin (Sierra College, William Jessup University)
# ----
# this in a state: Sacramento :
# this in a state: East Sacramento (California State University, Sacramento, Lincoln Law School of Sacramento)
# this in a state: Oak Park (University of the Pacific, McGeorge School of Law)
# ----
# this in a state: San Bernardino (California State University, San Bernardino, American Sports University)
# this in a state: San Diego (University of California, San Diego, San Diego State University, California Western School of Law, Thomas Jefferson School of Law, University of San Diego, Western Sierra Law School)
# ----
# ----
# ----
# this in a state: San Marcos (California State University San Marcos, University of St. Augustine for Health Sciences)
# this in a state: Santa Ana (Trinity Law School)
# ----
# ----
# this in a state: Santa Clarita (California Institute of the Arts, The Master's College, College of the Canyons)
# ----
# this in a state: Santa Monica (Santa Monica College)
# ----
# this in a state: Seaside (Monterey College of Law)
# this in a state: Simi Valley
# ----
# ----
# this in a state: Sunnyvale[14]
# this in a state: Temecula
# this in a state: Torrance
# this in a state: Thousand Oaks (California Lutheran University)
# this in a state: Turlock (California State University, Stanislaus)
# ----
# ----
# this in a state: Victorville
# ----
# this in a state: Westminster
# this in a state: West Covina
# this in a state: Whittier (Whittier College, Rio Hondo College)
# this in a state: Colorado[edit]
# ----
# this in a state: Aurora (Columbia College–Aurora, Ecotech Institute, University of Colorado Denver at the Anschutz Medical Campus, Colorado Community College System)
# ----
# this in a state: Colorado Springs (University of Colorado Colorado Springs, Colorado College, Colorado Technical University)
# ----
# ----
# ----
# this in a state: Golden (Colorado School of Mines)
# this in a state: Grand Junction (Colorado Mesa University)
# this in a state: Greeley (University of Northern Colorado)
# ----
# this in a state: Lakewood (Colorado Christian University)
# this in a state: Pueblo (Colorado State University–Pueblo)
# this in a state: Connecticut[edit]
# this in a state: Bridgeport (St. Vincent's College, University of Bridgeport)
# this in a state: Danbury (Western Connecticut State University)
# this in a state: East Hartford (Goodwin College)
# ----
# this in a state: Farmington (UConn Health)
# this in a state: Hamden (Quinnipiac University)
# this in a state: Hartford (Rensselaer at Hartford, Trinity College, University of Connecticut School of Law)
# this in a state: Middletown (Wesleyan University)
# this in a state: New Britain (Central Connecticut State University)
# ----
# ----
# this in a state: Southington (New England Baptist College)
# this in a state: Stamford (University of Connecticut, University of Bridgeport and Sacred Heart University branch campuses)
# ----
# this in a state: Waterbury (Post University, University of Bridgeport (Regional Campus), University of Connecticut (Regional Campus / Downtown Waterbury), Western Connecticut State University (Regional Campus))
# ----
# this in a state: West Hartford (University of Hartford, University of Saint Joseph, University of Connecticut Greater Hartford campus)
# ----
# this in a state: Delaware[edit]
# ----
# ----
# this in a state: New Castle (Wilmington University)
# this in a state: Wilmington (Delaware College of Art & Design, Drexel University – Wilmington Campus, Springfield College – Wilmington Campus, Widener University–Delaware Campus)
# this in a state: District of Columbia[edit]
# ----
# this in a state: Florida[edit]
# this in a state: Ave Maria (Ave Maria University)
# this in a state: Boca Raton (Florida Atlantic University)
# this in a state: Bradenton (Lake Erie College of Osteopathic Medicine branch campus)
# this in a state: Brandon
# this in a state: Cape Coral (Florida Gulf Coast University satellite facility)
# this in a state: Coral Gables (University of Miami)
# this in a state: Coral Springs (Barry University, Nova Southeastern University and Broward College)
# this in a state: Davie (Nova Southeastern University)
# this in a state: Daytona Beach (Embry–Riddle Aeronautical University)
# ----
# this in a state: Estero (Florida Gulf Coast University)
# this in a state: Fort Lauderdale (Broward College BC (Willis Holcombe Downtown Center), City College, Florida Atlantic University FAU (satellite campus), Florida International University FIU (satellite campus), Keiser University, Nova Southeastern University NSU (satellite campus), The Art Institute of Fort Lauderdale, University of Phoenix (Cypress Creek Learning Center), Jersey College)
# this in a state: Fort Myers (Florida Gulf Coast University)
# ----
# this in a state: Gulfport (Stetson University College of Law, St. Petersburg College, University of South Florida branch campus)
# this in a state: Hialeah (College of Business and Technology, Florida National University)
# this in a state: Hollywood
# this in a state: Jacksonville (University of North Florida, Jacksonville University, Florida State College at Jacksonville, University of Florida second campus, Florida Coastal School of Law and Jones College)
# this in a state: Kendall (Keiser College, Miami-Dade College (Kendall Campus), Nova Southeastern University (Miami Student Educational Center), College of Business and Technology (Kendall Campus))
# this in a state: Lakeland (Florida Polytechnic University)
# this in a state: Miami (Florida International University)
# this in a state: Miami Gardens (St. Thomas University, Florida Memorial University, CBT College)
# this in a state: Miramar (Broward College (Miramar Town Center), Broward College (Miramar West Center), Florida International University (FIU) (Miramar West Center), Nova Southeastern University (Miramar Campus))
# ----
# this in a state: Pembroke Pines (The Broward-Pines Center regional campus of Barry University, The Broward-Pines Center regional campus of Broward College,The Broward-Pines Center regional campus of Florida International University,The South regional campus of Broward College, Keiser University Pembroke Pines Campus)
# this in a state: Pensacola (University of West Florida)
# this in a state: Port St. Lucie (Indian River State College, Barry University, and Keiser University)
# this in a state: Orlando (University of Central Florida)
# this in a state: Sarasota (New College of Florida, Ringling College of Art and Design, State College of Florida, Manatee-Sarasota, University of South Florida Sarasota-Manatee)
# ----
# this in a state: St. Leo (St. Leo University)
# this in a state: St. Petersburg (University of South Florida St. Petersburg, Eckerd College, St. Petersburg College)
# this in a state: Sunrise
# this in a state: Tallahassee (Florida State University, Florida A&M University)
# this in a state: Tampa (University of South Florida)
# this in a state: West Palm Beach (Palm Beach Atlantic University, Keiser University)
# this in a state: Georgia[edit]
# this in a state: Albany (Albany State University)
# ----
# ----
# this in a state: Downtown (Georgia State University)
# this in a state: Druid Hills (Emory University)
# this in a state: Midtown (John Marshall Law School)
# this in a state: Augusta (Augusta Technical College, Augusta University, Paine College, East Georgia State College)
# this in a state: Blue Ridge (University of North Georgia)
# ----
# ----
# this in a state: Columbus (Columbus State University, Columbus Technical College)
# this in a state: Cumming (University of North Georgia)
# ----
# ----
# ----
# this in a state: Gainesville (University of North Georgia Gainesville Campus, Brenau University)
# this in a state: Glennville (Southeastern Technical College)
# this in a state: Kennesaw (Kennesaw State University)
# this in a state: Macon (Mercer University, Middle Georgia State University, Wesleyan College, Central Georgia Technical College, Fort Valley State University - satellite campus, Georgia College & State University - satellite campus)
# ----
# this in a state: Monroe
# ----
# this in a state: Oxford (Oxford College)
# this in a state: Rome (Berry College, Shorter University)
# ----
# ----
# this in a state: Swainsboro (East Georgia State College, Southeastern Technical College)
# ----
# this in a state: Vidalia (Southeastern Technical College)
# ----
# this in a state: Watkinsville (University of North Georgia)
# ----
# this in a state: Hawaii[edit]
# ----
# this in a state: Laie (Brigham Young University-Hawai'i)
# this in a state: Idaho[edit]
# this in a state: Boise (Boise State University, University of Idaho - satellite campus, Idaho State University - satellite campus, Concordia University School of Law)
# this in a state: Caldwell (College of Idaho)
# this in a state: Lewiston (Lewis-Clark State College)
# ----
# this in a state: Nampa (Northwest Nazarene University)
# ----
# ----
# this in a state: Illinois[edit]
# this in a state: Alton (Southern Illinois University School of Dental Medicine)
# this in a state: Aurora
# ----
# ----
# ----
# this in a state: Chicago :
# this in a state: North Park (Northeastern Illinois University)
# this in a state: Roseland (Chicago State University)
# this in a state: University Village/Little Italy (University of Illinois at Chicago)
# this in a state: Deerfield (Trinity International University)
# ----
# this in a state: Downers Grove (Midwestern University)
# ----
# this in a state: Elgin (Judson University)
# ----
# this in a state: Joliet (University of St. Francis)
# ----
# ----
# this in a state: Naperville (North Central College, Northern Illinois University satellite campus, DePaul University satellite campus, College of DuPage Naperville Regional Center, Governors State University satellite campus, Northwestern College Naperville campus, University of Illinois at Urbana–Champaign Business & Industry Services campus)
# ----
# this in a state: Peoria (Bradley University)
# this in a state: Rock Island (Augustana College)
# this in a state: Rockford (Rockford University)
# this in a state: Springfield (University of Illinois at Springfield)
# this in a state: University Park (Governors State University)
# this in a state: Indiana[edit]
# this in a state: Angola (Trine University)
# ----
# this in a state: Columbus (Indiana University – Purdue University Columbus)
# this in a state: Crawfordsville (Wabash College)
# this in a state: Fort Wayne (Indiana University – Purdue University Fort Wayne)
# this in a state: Gary (Indiana University Northwest)
# ----
# ----
# this in a state: Indianapolis (Indiana University – Purdue University Indianapolis)
# this in a state: Kokomo (Indiana University Kokomo)
# ----
# ----
# this in a state: New Albany (Indiana University Southeast)
# this in a state: Notre Dame (University of Notre Dame, Saint Mary's College, and Holy Cross College)
# ----
# ----
# ----
# ----
# ----
# this in a state: Valparaiso (Valparaiso University)
# ----
# this in a state: Iowa[edit]
# ----
# this in a state: Bettendorf (Upper Iowa University – satellite campus)
# ----
# this in a state: Cedar Rapids (Coe College)
# this in a state: Davenport (Saint Ambrose University, Hamilton Technical College)
# ----
# this in a state: Des Moines (Drake University, Grand View University, Mercy College of Health Sciences, University of Iowa two satellite facilities, AIB College of Business, Des Moines University)
# ----
# ----
# this in a state: Indianola (Simpson College)
# ----
# ----
# this in a state: Moline (Western Illinois University-Quad Cities)
# this in a state: Mount Vernon (Cornell College)
# ----
# this in a state: Oskaloosa (William Penn University)
# ----
# ----
# ----
# this in a state: Kansas[edit]
# ----
# ----
# ----
# this in a state: Kansas City (Donnelly College, Kansas Christian College, University of Kansas Medical Center (home of KU's Schools of Medicine, Nursing and Allied Health))
# ----
# ----
# this in a state: Olathe (MidAmerica Nazarene University)
# this in a state: Overland Park (Ottawa University adult campus, University of Kansas-Edwards Campus, Baker University Overland Park Campus, Emporia State University - Overland Park Campus (Metro Learning Center), Kansas Christian College, Rasmussen College)
# ----
# this in a state: Topeka (Washburn University, Friends University, Washburn Institute of Technology (Formerly Kaw Area Technical School), Baker University School of Nursing)
# this in a state: Wichita (Wichita State University (WSU), Friends University - main campus, Newman University, University of Kansas School of Medicine - Wichita campus)
# this in a state: Kentucky[edit]
# this in a state: Barbourville (Union College)
# this in a state: Berea (Berea College)
# this in a state: Bowling Green (Western Kentucky University)
# this in a state: Campbellsville (Campbellsville University)
# ----
# this in a state: Crestview Hills (Thomas More College)
# this in a state: Danville (Centre College, Bluegrass Community and Technical College, Eastern Kentucky University, Midway University, American National University)
# this in a state: Frankfort (Kentucky State University)
# this in a state: Georgetown (Georgetown College)
# this in a state: Grayson (Kentucky Christian University)
# ----
# this in a state: Lexington (University of Kentucky, Transylvania University)
# this in a state: Louisville (University of Louisville, Bellarmine University, Simmons College of Kentucky, Spalding University, Sullivan University)
# this in a state: Midway (Midway University)
# ----
# ----
# ----
# this in a state: Pikeville (University of Pikeville)
# ----
# ----
# ----
# this in a state: Louisiana[edit]
# this in a state: Baton Rouge (Louisiana State University, Southern University and A&M College, Southern University Law Center)
# ----
# ----
# this in a state: Lafayette (University of Louisiana at Lafayette)
# this in a state: Metairie
# ----
# ----
# ----
# ----
# this in a state: Shreveport (Southern University at Shreveport)
# ----
# this in a state: Maine[edit]
# ----
# this in a state: Bangor (University of Maine)
# this in a state: Bar Harbor (College of the Atlantic)
# this in a state: Biddeford (University of New England)
# this in a state: Brunswick (Bowdoin College)
# ----
# this in a state: Fort Kent (University of Maine at Fort Kent)
# ----
# this in a state: Lewiston (Bates College)
# this in a state: Machias (University of Maine at Machias)
# ----
# this in a state: Portland (Maine College of Art, University of Maine School of Law, University of New England (formerly Westbrook College), University of Southern Maine)
# this in a state: Presque Isle (University of Maine at Presque Isle)
# this in a state: Waterville (Thomas College, Colby College)
# this in a state: Maryland[edit]
# this in a state: Annapolis (United States Naval Academy, St. John's College)
# ----
# ----
# ----
# this in a state: Columbia (University of Phoenix, Lincoln College of Technology, Loyola University Maryland, University of Maryland, Baltimore County, Maryland University of Integrative Health, and Johns Hopkins University)
# this in a state: Cumberland (Allegany College of Maryland)
# ----
# ----
# this in a state: Germantown (Montgomery College branch campus)
# ----
# ----
# this in a state: Silver Spring (Montgomery College Takoma Park/Silver Spring campus, Howard University School of Continuing Education)
# this in a state: Takoma Park (Washington Adventist University, Montgomery College (Takoma Park/Silver Spring Campus))
# ----
# this in a state: Westminster (McDaniel College)
# this in a state: Massachusetts[edit]
# this in a state: Boston (Boston University, Boston College, Boston Conservatory, New England Conservatory, Brandeis University, Northeastern University, UMass Boston, Emmanuel College, Bunker Hill Community College, Roxbury Community College, Suffolk University, Simmons College, among many others)
# ----
# this in a state: Brookline (Pine Manor College, Hellenic College, Newbury College, parts of Boston University, parts of Boston Collegepart of the Wheelock College campus, Northeastern University's Parsons Field, Boston Graduate School of Psychoanalysis)
# ----
# this in a state: Chestnut Hill (Boston College)
# this in a state: The Colleges of Worcester Consortium:
# this in a state: Dudley (Nichols College)
# this in a state: North Grafton (Cummings School of Veterinary Medicine at Tufts University)
# this in a state: Paxton (Anna Maria College)
# this in a state: Worcester (Assumption, Becker, Clark University, Holy Cross, Mass. College of Pharmacy & Health Sciences, Quinsigamond Community College, UMass Medical School, Worcester State University, Worcester Polytechnic Institute)
# this in a state: Dartmouth (University of Massachusetts Dartmouth)
# this in a state: The Five College Region of Western Massachusetts:
# ----
# this in a state: Northampton (Smith College)
# this in a state: South Hadley (Mount Holyoke College)
# this in a state: Fitchburg (Fitchburg State College)
# this in a state: Framingham (Framingham State University)
# this in a state: Quincy (Eastern Nazarene College)
# this in a state: Lowell (University of Massachusetts Lowell)
# this in a state: Medford (Tufts University)
# this in a state: Newton (Boston College, Boston College Law School, Hebrew College, Mount Ida College, Lasell College, William James College, formerly Massachusetts School of Professional Psychology)
# this in a state: North Adams (Massachusetts College of Liberal Arts)
# this in a state: Somerville (Tufts University parts of the main campus)
# this in a state: Springfield (American International College, Springfield College, Western New England College)
# this in a state: Waltham (Bentley University, Brandeis University)
# ----
# ----
# this in a state: Williamstown (Williams College)
# this in a state: Michigan[edit]
# this in a state: Adrian (Adrian College, Siena Heights University)
# ----
# this in a state: Allendale (Grand Valley State University)
# this in a state: Alma (Alma College)
# ----
# ----
# ----
# this in a state: Dearborn (University of Michigan–Dearborn, Henry Ford College, Concordia University Dearborn Center, Central Michigan University)
# this in a state: Detroit :
# this in a state: Boston–Edison Historic District (Sacred Heart Major Seminary)
# this in a state: Downtown (University of Detroit Mercy School of Law)
# this in a state: Fitzgerald (Marygrove College)
# this in a state: Midtown (Wayne State University)
# this in a state: University District (University of Detroit Mercy)
# ----
# this in a state: Flint (Kettering University, University of Michigan-Flint)
# this in a state: Genoa Township (Cleary University main campus)
# this in a state: Grand Rapids (Aquinas College, Calvin College, Cornerstone University, Kuyper College, Thomas M. Cooley Law School satellite campus, Northwood University satellite campus, Grand Valley State University satellite campus, Ferris State University, Western Michigan University satellite campus, Grand Rapids Campus of the Michigan State University College of Human Medicine)
# this in a state: Hillsdale (Hillsdale College)
# this in a state: Holland (Hope College)
# ----
# ----
# this in a state: Lansing (Western Michigan University Cooley Law School)
# ----
# this in a state: Midland (Northwood University)
# ----
# ----
# this in a state: Saginaw (Saginaw Valley State University)
# this in a state: Sault Ste. Marie (Lake Superior State University)
# ----
# this in a state: Sterling Heights
# ----
# this in a state: Warren (Davenport University satellite campus, Warren Center for Central Michigan University, Wayne State University's Advanced Technology Education Center)
# this in a state: Minnesota[edit]
# ----
# ----
# ----
# this in a state: Faribault (South Central College)
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: North Mankato (South Central College)
# this in a state: Rochester (Mayo Medical School)
# ----
# ----
# this in a state: Saint Paul (Saint Catherine University, Concordia University, Hamline University, Macalester College, University of St. Thomas, Metropolitan State University, Saint Paul College, Mitchell Hamline School of Law)
# ----
# ----
# this in a state: Mississippi[edit]
# this in a state: Blue Mountain (Blue Mountain College)
# ----
# this in a state: Clinton (Mississippi College)
# ----
# ----
# this in a state: Holly Springs (Rust College)
# ----
# this in a state: Jackson (Jackson State University, Millsaps College, Belhaven University, Mississippi College School of Law)
# this in a state: Laurel (Southeastern Baptist College)
# ----
# this in a state: Southaven (University of Mississippi, Northwest Mississippi Community College)
# ----
# this in a state: Tougaloo (Tougaloo College)
# this in a state: Missouri[edit]
# ----
# ----
# ----
# ----
# this in a state: Fulton (Westminster College, William Woods University)
# ----
# ----
# ----
# ----
# this in a state: Montana[edit]
# this in a state: Billings (Montana State University Billings, Rocky Mountain College, Yellowstone Baptist College)
# ----
# this in a state: Butte (Montana Tech)
# ----
# this in a state: Great Falls (University of Great Falls, Great Falls College Montana State University)
# this in a state: Havre (Montana State University–Northern)
# this in a state: Helena (Carroll College, Helena College University of Montana)
# ----
# this in a state: Nebraska[edit]
# this in a state: Bellevue (Bellevue University)
# ----
# ----
# this in a state: Fremont (Midland University)
# this in a state: Hastings (Hastings College)
# ----
# ----
# this in a state: Omaha (Creighton University, Clarkson College, College of Saint Mary, Grace University, Nebraska Methodist College)
# ----
# ----
# ----
# this in a state: York, Nebraska (York College)
# this in a state: Nevada[edit]
# this in a state: Henderson (Nevada State College, National University, Roseman University of Health Sciences, Touro University Nevada)
# this in a state: Incline Village (Sierra Nevada College)
# this in a state: Las Vegas (University of Nevada, Las Vegas)
# this in a state: North Las Vegas (Cheyenne Campus of the College of Southern Nevada)
# this in a state: Reno (University of Nevada, Reno)
# this in a state: New Hampshire[edit]
# this in a state: Concord (NHTI, Concord's Community College, Granite State College, University of New Hampshire School of Law, Franklin Pierce University Doctorate of Physical Therapy program)
# ----
# ----
# this in a state: Henniker (New England College)
# ----
# this in a state: Manchester (University of New Hampshire at Manchester, Southern New Hampshire University, New Hampshire Institute of Art)
# this in a state: New London (Colby–Sawyer College)
# ----
# this in a state: Rindge (Franklin Pierce University)
# this in a state: New Jersey[edit]
# this in a state: Ewing (The College of New Jersey, Rider University)
# this in a state: Jersey City (New Jersey City University, Saint Peter's University)
# ----
# this in a state: Hoboken (Stevens Institute of Technology)
# this in a state: Madison (Drew University, Fairleigh Dickinson University, College of Saint Elizabeth)
# ----
# this in a state: Newark (Rutgers University, New Jersey Institute of Technology, UMDNJ)
# ----
# this in a state: Paterson
# ----
# this in a state: Union (Kean University)
# this in a state: West Long Branch (Monmouth University)
# this in a state: New Mexico[edit]
# this in a state: Albuquerque (University of New Mexico, Southwest University of Visual Arts, Southwestern Indian Polytechnic Institute, Trinity Southwest University, University of St. Francis College of Nursing and Allied Health Department of Physician Assistant Studies, St. Norbert College Master of Theological Studies program; New Mexico State University, Highlands University, Lewis University, Wayland Baptist University, and Webster University; Brookline College, Pima Medical Institute, National American University, Grand Canyon University, the University of Phoenix and several barber/beauty colleges have established their presence in the area.)
# ----
# ----
# ----
# ----
# this in a state: Rio Rancho
# ----
# ----
# this in a state: New York[edit]
# this in a state: Albany (SUNY Albany, Siena College, Albany College of Pharmacy, Albany Law School, Albany Medical College, College of Saint Rose, Excelsior College, Maria College of Albany, Mildred Elley, Sage College of Albany)
# ----
# ----
# ----
# ----
# this in a state: Buffalo (University at Buffalo, Buffalo State College, Canisius College, Daemen College, D'Youville College, Medaille College, Villa Maria College)
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Geneva (Hobart and William Smith Colleges)
# ----
# ----
# this in a state: Newburgh (Mount Saint Mary College)
# ----
# this in a state: New Rochelle (Iona College)
# this in a state: New York City (Columbia University, Barnard College, Teachers College, Manhattan School of Music, Jewish Theological Seminary, Union Theological Seminary, Bank Street College of Education)
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Seneca Falls (New York Chiropractic College)
# this in a state: Stony Brook (Stony Brook University)
# ----
# this in a state: Tivoli (Bard College)
# this in a state: Troy (Rensselaer Polytechnic Institute, Russell Sage College, Hudson Valley Community College)
# this in a state: Valhalla (New York Medical College)
# this in a state: West Point (United States Military Academy)
# this in a state: Yonkers (Sarah Lawrence College)
# this in a state: North Carolina[edit]
# ----
# this in a state: Banner Elk (Lees-McRae College)
# this in a state: Belmont (Belmont Abbey College)
# ----
# ----
# this in a state: Brevard (Brevard College)
# ----
# this in a state: Cary
# ----
# this in a state: Charlotte (Johnson C. Smith University , Johnson & Wales University, Queens University of Charlotte, Charlotte School of Law)
# ----
# ----
# ----
# this in a state: Elizabeth City (Mid-Atlantic Christian University)
# ----
# this in a state: Fayetteville (Methodist University)
# this in a state: Greensboro (University of North Carolina at Greensboro, Greensboro College, Guilford College, North Carolina A & T State University, Bennett College, Elon University School of Law)
# ----
# ----
# this in a state: High Point (High Point University)
# this in a state: Laurinburg (St. Andrews University)
# ----
# this in a state: Misenheimer (Pfeiffer University)
# this in a state: Montreat (Montreat College)
# ----
# this in a state: Murfreesboro (Chowan University)
# ----
# ----
# this in a state: Rocky Mount (North Carolina Wesleyan College)
# this in a state: Salisbury (Catawba College)
# this in a state: Wilmington (University of North Carolina at Wilmington)
# this in a state: Wilson (Barton College )
# ----
# this in a state: Winston-Salem (Wake Forest University, University of North Carolina School of the Arts, Salem College, Winston-Salem State University)
# this in a state: North Dakota[edit]
# this in a state: Bismarck (University of Mary, Rasmussen College)
# this in a state: Dickinson (Dickinson State University)
# ----
# ----
# this in a state: Jamestown (University of Jamestown)
# this in a state: Mayville (Mayville State University)
# this in a state: Minot (Minot State University)
# this in a state: Valley City (Valley City State University)
# this in a state: Ohio[edit]
# ----
# this in a state: Akron (University of Akron)
# this in a state: Alliance (University of Mount Union)
# ----
# ----
# this in a state: Berea (Baldwin Wallace College)
# ----
# ----
# ----
# ----
# this in a state: Cleveland:[46]
# this in a state: Downtown (Cleveland State University, Cuyahoga Community College)
# this in a state: Fairfax (Cleveland Clinic Lerner College of Medicine)
# this in a state: St. Clair-Superior (Ohio Technical College)
# this in a state: University Circle (Case Western Reserve University)
# this in a state: Columbus :
# this in a state: Downtown (Capital University Law School, Columbus College of Art and Design, Franklin University)
# this in a state: North Central neighborhood (Ohio Dominican University)
# this in a state: University District (Ohio State University)
# ----
# this in a state: Delaware (Ohio Wesleyan University)
# this in a state: Fairborn (Wright State University)
# this in a state: Findlay (University of Findlay)
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Perrysburg Township (Owens Community College)
# ----
# this in a state: Springfield (Wittenberg University)
# this in a state: Tiffin (Tiffin University, Heidelberg University)
# this in a state: Toledo (University of Toledo, University of Toledo College of Medicine and Life Sciences, Davis College, Mercy College of Ohio)
# ----
# this in a state: Wooster (College of Wooster)
# this in a state: Yellow Springs (Antioch College, Antioch University Midwest)
# this in a state: Youngstown (Youngstown State University)
# this in a state: Oklahoma[edit]
# ----
# ----
# this in a state: Bethany (Southern Nazarene University)
# ----
# ----
# ----
# ----
# ----
# this in a state: Midwest City (Rose State College)
# ----
# this in a state: Oklahoma City (Oklahoma City University, University of Oklahoma - OU Medicine and the University of Oklahoma Health Sciences Center campuses, Oklahoma State University–Oklahoma City)
# ----
# ----
# this in a state: Tulsa (University of Tulsa)
# this in a state: Weatherford (Southwestern Oklahoma State University)
# this in a state: Oregon[edit]
# ----
# ----
# ----
# this in a state: Forest Grove (Pacific University)
# this in a state: Klamath Falls (Klamath Community College, Oregon Institute of Technology)
# ----
# this in a state: Lebanon (Western University of Health Sciences Oregon Branch: College of Osteopathic Medicine of the Pacific, Northwest)
# this in a state: Marylhurst (Marylhurst University)
# this in a state: McMinnville (Linfield College)
# ----
# this in a state: Newberg (George Fox University)
# this in a state: Portland (Portland State University, Oregon Health & Science University, Portland Community College, University of Portland, Lewis & Clark College ....)
# this in a state: Salem (Chemeketa Community College, Corban University, Tokyo International University of America, Willamette University)
# this in a state: Pennsylvania[edit]
# this in a state: Allentown (Cedar Crest College, Muhlenberg College, a satellite campus of Lehigh Carbon Community College (LCCC))
# this in a state: Altoona (Penn State Altoona)
# ----
# this in a state: Bethlehem (Lehigh University, Moravian College)
# ----
# this in a state: Bradford (University of Pittsburgh at Bradford)
# ----
# this in a state: Carlisle (Dickinson College, Penn State Dickinson School of Law)
# this in a state: Center Township, Beaver County (Penn State Beaver)
# this in a state: Center Valley (DeSales University, Penn State Lehigh Valley, Strayer University (Allentown campus))
# this in a state: Chambersburg (Wilson College)
# ----
# this in a state: Collegeville (Ursinus College)
# ----
# this in a state: Dunmore (Pennsylvania State University)
# this in a state: Easton (Lafayette College)
# ----
# ----
# this in a state: Erie (Gannon University, Mercyhurst College, Penn State Erie, Lake Erie College of Osteopathic Medicine)
# ----
# this in a state: Grantham (Messiah College)
# this in a state: Greensburg (Seton Hill University, University of Pittsburgh at Greensburg, Lake Erie College of Osteopathic Medicine branch campus)
# ----
# this in a state: Harrisburg (Temple University Harrisburg Campus, Widener University Harrisburg Campus including its School of Law, Harrisburg University of Science and Technology, Messiah College's Harrisburg Institute, Penn State Harrisburg Eastgate Center, Dixon University Center, Harrisburg Area Community College)
# this in a state: Hershey (Penn State Hershey Medical Center)
# ----
# ----
# this in a state: Johnstown :
# this in a state: Richland Township (University of Pittsburgh at Johnstown)
# this in a state: Kennett Square (University of Pennsylvania School of Veterinary Medicine)
# ----
# this in a state: Lancaster (Franklin & Marshall)
# this in a state: Lemoyne (Duquesne University (Capital Region Campus))
# ----
# ----
# ----
# this in a state: Lower Merion Township (Bryn Mawr College, Harcum College, Rosemont College, St. Charles Borromeo Seminary)
# this in a state: Merion (Saint Joseph's University)
# ----
# this in a state: Meadville (Allegheny College)
# this in a state: Mechanicsburg (Messiah College)
# this in a state: Mont Alto (Penn State Mont Alto)
# ----
# ----
# this in a state: North East (Mercyhurst North East)
# this in a state: Philadelphia :
# this in a state: Cecil B. Moore (Temple University, Girard College)
# this in a state: Center City (Temple University Center City Campus, Drexel University Center City Hahnemann Campus, Thomas Jefferson University)
# this in a state: Chestnut Hill (Chestnut Hill College)
# this in a state: East Falls (Drexel University Queen Lane Campus, Philadelphia University)
# this in a state: Germantown (La Salle University)
# this in a state: Logan (La Salle University (main campus))
# this in a state: Northeast Philadelphia (Holy Family University)
# this in a state: Overbrook (Saint Joseph's University Overbrook campus)
# this in a state: Rittenhouse Square (University of the Arts, Peirce College)
# this in a state: University City (University of Pennsylvania, Drexel University, University of the Sciences in Philadelphia, Community College of Philadelphia, Lincoln University, The Restaurant School at Walnut Hill College, Philadelphia Divinity School, Philadelphia College of Osteopathy)
# this in a state: Pittsburgh:[48]
# this in a state: Central Northside (Community College of Allegheny County)
# this in a state: Downtown Pittsburgh (Point Park University, The Art Institute of Pittsburgh)
# this in a state: East Liberty (Pittsburgh Institute of Mortuary Science)
# this in a state: Oakland (Carnegie Mellon University, University of Pittsburgh, Carlow University)
# this in a state: Squirrel Hill (Chatham University)
# this in a state: Uptown neighborhood (Duquesne University)
# this in a state: Reading (Albright College, Alvernia University, Penn State Berks)
# this in a state: Scranton (University of Scranton, The Commonwealth Medical College, Johnson College, Lackawanna College, Marywood University, Fortis Institute)
# ----
# ----
# ----
# ----
# this in a state: Summerdale (Central Pennsylvania College)
# this in a state: Swarthmore (Swarthmore College)
# this in a state: Upper Dublin Township (Temple University Ambler and Fort Washington campuses, DeVry University Fort Washington campus and Gwynedd Mercy College Fort Washington campus)
# this in a state: Villanova (Villanova University)
# this in a state: Waynesburg (Waynesburg University)
# this in a state: West Chester (West Chester University of Pennsylvania)
# this in a state: Wilkes-Barre (King's College, Wilkes University)
# ----
# this in a state: Rhode Island[edit]
# ----
# ----
# this in a state: Newport (Salve Regina University)
# this in a state: Providence :
# this in a state: College Hill (Brown University - main campus, Rhode Island School of Design)
# ----
# this in a state: Elmhurst (Providence College)
# this in a state: Jewelry District (Brown University - Alpert Medical School, Johnson and Wales University)
# this in a state: Lower South Providence (Community College of Rhode Island)
# this in a state: Manton (Rhode Island College)
# this in a state: Smithfield (Bryant University)
# this in a state: Warwick (Community College of Rhode Island)
# this in a state: South Carolina[edit]
# ----
# ----
# this in a state: Charleston (College of Charleston, The Citadel, MUSC, Charleston School of Law)
# ----
# this in a state: Clinton (Presbyterian College)
# ----
# this in a state: Due West (Erskine College)
# this in a state: Florence (Francis Marion University)
# this in a state: Greenwood (Lander University)
# this in a state: North Charleston (Charleston Southern University, Trident Technical College - Main Campus)
# ----
# this in a state: Rock Hill (Winthrop University)
# this in a state: Spartanburg (Wofford College, Converse College, University of South Carolina Upstate, Spartanburg Methodist College, Edward Via College of Osteopathic Medicine, Spartanburg Community College, Virginia College, Sherman College of Chiropractic)
# this in a state: South Dakota[edit]
# this in a state: Aberdeen
# ----
# this in a state: Madison (Dakota State University)
# this in a state: Sioux Falls (University of Sioux Falls, Augustana University, Sioux Falls Seminary, Kilian Community College, Southeast Technical Institute, National American University, South Dakota School for the Deaf, Globe University/Minnesota School of Business, University of South Dakota's Sanford School of Medicine (Sioux Falls campus), Stewart School, South Dakota Public Universities and Research Center (USDSU))
# this in a state: Spearfish (Black Hills State University)
# ----
# this in a state: Tennessee[edit]
# this in a state: Chattanooga (University of Tennessee at Chattanooga)
# this in a state: Clarksville (Austin Peay State University, Miller-Motte Technical College, Nashville State Community College, Daymar Institute, North Tennessee Bible Institute)
# this in a state: Collegedale (Southern Adventist University)
# ----
# ----
# ----
# this in a state: Johnson City (East Tennessee State University)
# this in a state: Knoxville (University of Tennessee, Duncan School of Law (Lincoln Memorial Univ.))
# this in a state: Lebanon (Cumberland University)
# ----
# this in a state: Memphis (Baptist College of Health Sciences, Christian Brothers University, LeMoyne-Owen College, Memphis College of Art, Rhodes College, Southern College of Optometry, Southwest Tennessee Community College, Union University - Germantown campus, University of Memphis, University of Tennessee Health Science Center
# ----
# this in a state: Memphis (Christian Brothers University, LeMoyne-Owen College, Memphis College of Art, Rhodes College, Southern College of Optometry, Southwest Tennessee Community College, University of Memphis, University of Tennessee Health Science Center, Visible Music College)
# ----
# this in a state: Nashville (Vanderbilt University, Belmont University, Tennessee State University, Lipscomb University, Fisk University, Aquinas College, Trevecca Nazarene University, Meharry Medical College, Nashville School of Law)
# ----
# this in a state: Texas[edit]
# this in a state: Abilene (Abilene Christian University, Hardin-Simmons University, McMurry University)
# ----
# this in a state: Amarillo (Wayland Baptist University branch campus, Texas Tech University Health Sciences Center at Amarillo School of Pharmacy, Texas Tech University at Amarillo, West Texas A&M University satellite campus)
# this in a state: Arlington (University of Texas at Arlington)
# ----
# this in a state: Beaumont (Lamar University)
# this in a state: Big Spring (Howard College)
# this in a state: Brownsville (The University of Texas Rio Grande Valley)
# this in a state: Bryan (Blinn College – Bryan Campus, Texas A&M Health Science Center)
# ----
# this in a state: Carrollton
# ----
# ----
# this in a state: Corpus Christi (Texas A&M University-Corpus Christi, Del Mar College, Saint Leo University-Corpus Christi)
# this in a state: Dallas (University of Texas Southwestern Medical Center)
# ----
# this in a state: Edinburg (University of Texas Rio Grande Valley)
# this in a state: El Paso (University of Texas at El Paso)
# this in a state: Fort Worth (Texas Christian University, Texas Wesleyan University, Texas A&M School of Law)
# this in a state: Galveston (Texas A&M University at Galveston)
# this in a state: Georgetown (Southwestern University)
# this in a state: Garland (Amberton University)
# this in a state: Grand Prairie
# ----
# ----
# this in a state: Irving (University of Dallas, North Lake College)
# ----
# this in a state: Killeen (Central Texas College, Texas A&M University-Central Texas)
# ----
# this in a state: Laredo (Texas A&M International University, University of Texas Health Science Center at San Antonio - Laredo campus)
# this in a state: Lubbock (Texas Tech University, Lubbock Christian University)
# this in a state: McAllen (University of Texas Rio Grande Valley)
# this in a state: McKinney
# this in a state: Mesquite (Texas A&M University–Commerce Mesquite Metroplex Center, Columbia College-Mesquite Campus)
# ----
# this in a state: Odessa (The University of Texas of the Permian Basin)
# this in a state: Pasadena (University of Houston–Clear Lake)
# this in a state: Pearland (University of Houston–Clear Lake satellite campus)
# ----
# this in a state: Plano (Southern Methodist University branch campus, Dallas Baptist University satellite campus)
# ----
# this in a state: Richardson (University of Texas at Dallas main campus)
# this in a state: San Angelo (Angelo State University)
# this in a state: San Antonio (University of Texas at San Antonio, Texas A&M University–San Antonio, Trinity University, University of the Incarnate Word)
# ----
# ----
# this in a state: Texarkana (Texas A&M University–Texarkana)
# this in a state: Tyler (The University of Texas at Tyler)
# this in a state: University Park (Southern Methodist University)
# this in a state: Waco (Baylor University)
# this in a state: Wichita Falls (Midwestern State University)
# this in a state: Utah[edit]
# ----
# this in a state: Ephraim (Snow College)
# ----
# this in a state: Orem (Utah Valley University)
# ----
# this in a state: Salt Lake City (University of Utah)
# this in a state: South Jordan (Roseman University of Health Sciences College of Dental Medicine)
# this in a state: Vermont[edit]
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Virginia[edit]
# this in a state: Alexandria (Virginia Commonwealth University branch of its School of Social Work, The George Washington University)
# this in a state: Arlington (Marymount University, George Mason University)
# ----
# ----
# ----
# ----
# ----
# ----
# this in a state: Hampton (Hampton University, Bryant and Stratton College)
# ----
# ----
# this in a state: Lynchburg (Lynchburg College, Randolph College, Liberty University, Central Virginia Community College)
# this in a state: Newport News (Christopher Newport University)
# this in a state: Norfolk (Old Dominion University, Norfolk State University)
# this in a state: Portsmouth (Old Dominion University)
# ----
# this in a state: Richmond (University of Richmond, Virginia Commonwealth University)
# this in a state: Virginia Beach (Regent University, Atlantic University, Virginia Wesleyan College, University of Virginia and Virginia Tech satellite campuses, ECPI University)
# ----
# ----
# this in a state: Washington[edit]
# this in a state: Bellevue (Bellevue College, City University of Seattle)
# this in a state: Bellingham (Western Washington University)
# ----
# ----
# this in a state: Kent
# this in a state: Lakewood (Clover Park Technical College and Pierce College)
# this in a state: Parkland (Pacific Lutheran University)
# ----
# this in a state: Richland (Washington State University Tri-Cities)
# ----
# this in a state: Spokane (Gonzaga University, Whitworth University, EWU Spokane at the Riverpoint Campus, WSU Spokane)
# this in a state: Tacoma (University of Puget Sound, Tacoma Community College, City University of Seattle-Tacoma, Bates Technical College, The Evergreen State College Tacoma Campus, University of Washington Tacoma)
# this in a state: Vancouver (Washington State University Vancouver)
# this in a state: West Virginia[edit]
# ----
# this in a state: Beckley (West Virginia University Institute of Technology)
# ----
# this in a state: Charleston (branch campus of West Virginia University)
# this in a state: Elkins (Davis & Elkins College)
# ----
# ----
# ----
# this in a state: Institute (West Virginia State University)
# this in a state: Lewisburg (West Virginia School of Osteopathic Medicine, University of Charleston)
# ----
# ----
# ----
# this in a state: South Charleston (Marshall University – South Charleston Campus)
# ----
# this in a state: Wisconsin[edit]
# this in a state: Appleton (Lawrence University)
# this in a state: Eau Claire (University of Wisconsin–Eau Claire)
# this in a state: Green Bay (University of Wisconsin-Green Bay)
# this in a state: Kenosha (University of Wisconsin-Parkside, Carthage College, Kenosha campus of Gateway Technical College, National-Louis University, Herzing University)
# ----
# ----
# ----
# this in a state: Milwaukee (Marquette University, University of Wisconsin–Milwaukee, Cardinal Stritch University, Concordia University Wisconsin)
# this in a state: Oshkosh (University of Wisconsin–Oshkosh)
# ----
# ----
# ----
# this in a state: Waukesha (Carroll University)
# ----
# this in a state: Wyoming[edit]
# ----

# %% [markdown]
# This also didn't work.
#
# Maybe this is time to think about what might be unique about the states. We can eyeball the first few in the file, and we can take a look at the source page this came from to find something.
#
# https://en.wikipedia.org/wiki/List_of_college_towns
#
# Skimming through the wixipedia page shows us that there appearts to be an edit link next to each state name.  Is this duplitated through the file?

# %%
fileio = open('crappystatedata.txt', 'r')

text = fileio.read()

print(text.count('[edit]'))
fileio.close()
# Out:
# 51

# %% [markdown]
# So there are 51 results!  Yes, there are 50 states but District of Columbia is counted as a state.  Also you can look at the outline of the page and it shows that there are 51 sections.
#
# We might think about now splitting the text on this [edit] text since it does mark the start of a new section.
#
# However, when we do that we end up with this:

# %%
fileio = open('crappystatedata.txt', 'r')

text = fileio.read()
lines = text.split("[edit]")

print(lines[:2])
fileio.close()
# Out:
# ['Alabama', '\nAuburn (Auburn University, Edward Via College of Osteopathic Medicine)[7]\nBirmingham (University of Alabama at Birmingham, Birmingham School of Law, Cumberland School of Law, Miles Law School)[8]\nDothan (Fortis College, Troy University Dothan Campus, Alabama College of Osteopathic Medicine)\nFlorence (University of North Alabama)\nHomewood (Samford University)\nHuntsville (University of Alabama, Huntsville)\nJacksonville (Jacksonville State University)[9]\nLivingston (University of West Alabama)[9]\nMobile (University of South Alabama)[8]\nMontevallo (University of Montevallo, Faulkner University)[9]\nMontgomery (Alabama State University, Huntingdon College, Auburn University at Montgomery, H. Councill Trenholm State Technical College, Faulkner University)\nTroy (Troy University)[9][10]\nTuscaloosa (University of Alabama, Stillman College, Shelton State)[11][12]\nTuskegee (Tuskegee University)[13]\nAlaska']

# %% [markdown]
# The state names are now separated from their contents, and the name of the next state is at the end of the previous one's data.
#
# So that sucks.
#
# Since we can't use split here, we might want to just use a filter.  In this case, we know that [edit] comes at the end. So we can use .endswith to check if that's our line.

# %%
fileio = open('crappystatedata.txt', 'r')

text = fileio.read()
fileio.close()

lines = text.split("\n")

states = []

for line in lines:
    if line.endswith("[edit]"):
        print(line)
        states.append(line)

print(len(states))
# Out:
# Alabama[edit]
# Alaska[edit]
# Arizona[edit]
# Arkansas[edit]
# California[edit]
# Colorado[edit]
# Connecticut[edit]
# Delaware[edit]
# District of Columbia[edit]
# Florida[edit]
# Georgia[edit]
# Hawaii[edit]
# Idaho[edit]
# Illinois[edit]
# Indiana[edit]
# Iowa[edit]
# Kansas[edit]
# Kentucky[edit]
# Louisiana[edit]
# Maine[edit]
# Maryland[edit]
# Massachusetts[edit]
# Michigan[edit]
# Minnesota[edit]
# Mississippi[edit]
# Missouri[edit]
# Montana[edit]
# Nebraska[edit]
# Nevada[edit]
# New Hampshire[edit]
# New Jersey[edit]
# New Mexico[edit]
# New York[edit]
# North Carolina[edit]
# North Dakota[edit]
# Ohio[edit]
# Oklahoma[edit]
# Oregon[edit]
# Pennsylvania[edit]
# Rhode Island[edit]
# South Carolina[edit]
# South Dakota[edit]
# Tennessee[edit]
# Texas[edit]
# Utah[edit]
# Vermont[edit]
# Virginia[edit]
# Washington[edit]
# West Virginia[edit]
# Wisconsin[edit]
# Wyoming[edit]
# 51

# %% [markdown]
# There we have it!  We found a filter that correctly identifies our states, without any false positives of false negatives.
#
# Now that we can correctly find the markers for a state, we can turn our attention to what we might want to do about that getting the data under it.
#
# So we have two kinds of line:
#
# 1. lines that serve as a marke that a new state is reporting
# 2. lines of data about college towns, that all belong to the state that above it
#
# We need to decide what we want to do when we hit a nen state line.

# %% [markdown]
# ## the main/sub loop pattern
#
# Recall our previous pattern that dealt with lines, and you needed to act on those lines with another loop.  For example:
#
# ``` python
# for line in file:
#     loop through stuff in that line
#     add that collected data to the broader list
# ```
#
# Let's consider a final data structure here:
#
#
# ``` python
# [ ['state1', 'city1', 'city2'],
#   ['state2', 'city3', 'city4'] ]
# ```
#
# Our primary accumulator is our outermost list (the outside []).  It serves the purpose of collecting all the secondary accumulators.
#
# ## Analogy: making info packets
#
# Let's imagine a situation where you are assembling info packets for visiting candidates.  You have a table lined up with all the papers and packets to include.  You go down that table, grabbing one of each and pacing it on the bottom of your current pile.  At the end of the table, you staple all the papers together.  Finally, you put the packet into the box holding all the completed packets.
#
# That's a pretty defined accumulator pattern.  You just have to keep grabbing all the papers until there are none left to grab.
#
# Our data is a little different.
#
# ## Analogy: a sandwich maker
#
# Say you work at a sub sandwich shop.  A customer comes in and puts in an order.  There are a few standard things to do, but then you get to toppings.  Your job is to keep adding toppings to the sandwhich until they tell you they are done. You don't know how many times you'll add stuff to the sandwich, but you'll know when they say they are done.  Then you package up the sandwich and hand it to the customer.
#
# All the customers you have in the day is your primary accumulator, and the secondary accumulators are the single sandwiches that you make.
#
#
# ## OK so this still isn't perfect
#
# If finding a state line tells us that we need to start collecting a new bunch of data, then we need to decide what to do with the stuff we have previously collected.  Like a customer putting a bunch of shoe requests into you, and by the time you get back to them, they are gone and a new customer has a whole different set of requests.  You're still standing there with a bunch of shoes in your hand.
#
# When you see that new customer, you excuse yourself and put the previous order to the side.  This is more what we are after.  The customer itself does't tell us that we are done, the fact that we see a new customer tells us that the previous order is done.
#
# So here's our plan:
#
# * loop through the lines
# * when the line is city (so not a state):
#     * add that data to the secondary accumulator
# * what the line is a state:
#     * add secondary accumulator package to your primary accumulator
#     * reset the secondary accumulator back to empty
#     * add the state to that newly empty secondary accumulator
#
# We've sort of seen this before, where we had:
#
# ```python
# allstuff = []
#
# for line in file:
#     newthing = []
#     for something in line:
#         ...
#         newthing.append(stuff)
#     allstuff.append(newthing)
# ```
#
# `allstuff` is our primary accumulator and `newthing` is our secondary accumulator.  Because there's a very difinite place where we want to start over, we have `newthing = []` just inside our primary for loop, with the secondary loop adding to it.  This allows it to reset everytime we hit a new group.
#
# In our case, we are using a conditional to check when we need to reset things.  That reset process includes adding the currently accrued contents to the primary accumulator, and then setting the secondary accumulator back to empty.

# %%
fileio = open('crappystatedata.txt', 'r')

text = fileio.read()
lines = text.split("\n")

allchunks = []
statechunk = []

foundfirst = False

for line in lines:
    if line.endswith("[edit]") and foundfirst == False:
        print("This is the first state!", line)
        statechunk.append(line)
        foundfirst = True
    elif line.endswith("[edit]"):
        print("a new state has begun!", line)
        # add completed state
        allchunks.append(statechunk)
        # reset the chunk
        statechunk = [line]
    else:
        statechunk.append(line)
    allchunks.append(statechunk)
# Out:
# This is the first state! Alabama[edit]
# a new state has begun! Alaska[edit]
# a new state has begun! Arizona[edit]
# a new state has begun! Arkansas[edit]
# a new state has begun! California[edit]
# a new state has begun! Colorado[edit]
# a new state has begun! Connecticut[edit]
# a new state has begun! Delaware[edit]
# a new state has begun! District of Columbia[edit]
# a new state has begun! Florida[edit]
# a new state has begun! Georgia[edit]
# a new state has begun! Hawaii[edit]
# a new state has begun! Idaho[edit]
# a new state has begun! Illinois[edit]
# a new state has begun! Indiana[edit]
# a new state has begun! Iowa[edit]
# a new state has begun! Kansas[edit]
# a new state has begun! Kentucky[edit]
# a new state has begun! Louisiana[edit]
# a new state has begun! Maine[edit]
# a new state has begun! Maryland[edit]
# a new state has begun! Massachusetts[edit]
# a new state has begun! Michigan[edit]
# a new state has begun! Minnesota[edit]
# a new state has begun! Mississippi[edit]
# a new state has begun! Missouri[edit]
# a new state has begun! Montana[edit]
# a new state has begun! Nebraska[edit]
# a new state has begun! Nevada[edit]
# a new state has begun! New Hampshire[edit]
# a new state has begun! New Jersey[edit]
# a new state has begun! New Mexico[edit]
# a new state has begun! New York[edit]
# a new state has begun! North Carolina[edit]
# a new state has begun! North Dakota[edit]
# a new state has begun! Ohio[edit]
# a new state has begun! Oklahoma[edit]
# a new state has begun! Oregon[edit]
# a new state has begun! Pennsylvania[edit]
# a new state has begun! Rhode Island[edit]
# a new state has begun! South Carolina[edit]
# a new state has begun! South Dakota[edit]
# a new state has begun! Tennessee[edit]
# a new state has begun! Texas[edit]
# a new state has begun! Utah[edit]
# a new state has begun! Vermont[edit]
# a new state has begun! Virginia[edit]
# a new state has begun! Washington[edit]
# a new state has begun! West Virginia[edit]
# a new state has begun! Wisconsin[edit]
# a new state has begun! Wyoming[edit]

# %%
allchunks[-1]
# Out:
# ['Wyoming[edit]', 'Laramie (University of Wyoming)[13]']
